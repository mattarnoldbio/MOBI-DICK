# %%
import pandas as pd
import subprocess

# %%
families_virion = [line for line in open('/Users/arno01m/Downloads/VertVirusFamilies.txt')]
families_virion = [line[:-1] for line in families_virion]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 families_virion = [line for line in open('/Users/arno01m/Downloads/VertVirusFamilies.txt')]
#       2 families_virion = [line[:-1] for line in families_virion]
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/arno01m/Downloads/VertVirusFamilies.txt'

# %%
families_virion

non_vert_families =[
    "mitoviridae", "totiviridae", "partitiviridae", "iflaviridae", "dicistroviridae", 
    "virgaviridae", "picobirnaviridae", "retroviridae", "iridoviridae", 
    "alloherpesviridae", "geminiviridae", "caulimoviridae", "picobirnaviridae", 
    "chuviridae", "betaflexiviridae", "alphasatellitidae", "pospiviroidae", 
    "nanghoshaviridae", "secoviridae", "tospoviridae", "tolecusatellitidae", 
    "amnoonviridae", "bromoviridae", "tombusviridae", "tymoviridae", "tosoviridae", 
    "sunviridae", "carmotetraviridae", "chrysoviridae", "deltaflexiviridae", 
    "marseilleviridae", "nanhypoviridae", "bacilladnaviridae", "blumeviridae", 
    "mesoniviridae", "cremegaviridae", "olifoviridae", "qinviridae", "artoviridae", 
    "gresnaviridae", "endornaviridae", "mymonaviridae", "nenyaviridae", "tristromaviridae"
]

# %%
#vert_families = set(families_virion) - set(non_vert_families)

vert_families = ['anelloviridae', 'circoviridae', 'caliciviridae', 'reoviridae', 'matonaviridae', 'spinareoviridae', 'tobaniviridae', 'hepadnaviridae', 'nyamiviridae', 'hepeviridae', 'rhabdoviridae', 'sedoreoviridae', 'papillomaviridae', 'pneumoviridae', 'birnaviridae', 'astroviridae', 'vilyaviridae', 'genomoviridae', 'poxviridae', 'virgavirida', 'nodaviridae', 'hantaviridae', 'phenuiviridae', 'filoviridae', 'paramyxoviridae', 'adintoviridae', 'kolmioviridae', 'naryaviridae', 'flaviviridae', 'arenaviridae', 'redondoviridae', 'orthomyxoviridae', 'nairoviridae', 'asfarviridae', 'adenoviridae', 'herpesviridae', 'togaviridae', 'ViPR', 'peribunyaviridae', 'smacoviridae', 'bornaviridae', 'coronaviridae', 'parvoviridae', 'orthoherpesviridae', 'arteriviridae', 'polyomaviridae', 'picornaviridae']

# %%
print(list(vert_families))
# Out:
# ['anelloviridae', 'circoviridae', 'caliciviridae', 'reoviridae', 'matonaviridae', 'spinareoviridae', 'tobaniviridae', 'hepadnaviridae', 'nyamiviridae', 'hepeviridae', 'rhabdoviridae', 'sedoreoviridae', 'papillomaviridae', 'pneumoviridae', 'birnaviridae', 'astroviridae', 'vilyaviridae', 'genomoviridae', 'poxviridae', 'virgavirida', 'nodaviridae', 'hantaviridae', 'phenuiviridae', 'filoviridae', 'paramyxoviridae', 'adintoviridae', 'kolmioviridae', 'naryaviridae', 'flaviviridae', 'arenaviridae', 'redondoviridae', 'orthomyxoviridae', 'nairoviridae', 'asfarviridae', 'adenoviridae', 'herpesviridae', 'togaviridae', 'ViPR', 'peribunyaviridae', 'smacoviridae', 'bornaviridae', 'coronaviridae', 'parvoviridae', 'orthoherpesviridae', 'arteriviridae', 'polyomaviridae', 'picornaviridae']

# %%
virus_hits = pd.read_csv('/Users/arno01m/Downloads/batch2_final_viral_hits.csv')

vert_virus_hits = virus_hits[virus_hits['family'].isin(vert_families)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 virus_hits = pd.read_csv('/Users/arno01m/Downloads/batch2_final_viral_hits.csv')
#       3 vert_virus_hits = virus_hits[virus_hits['family'].isin(vert_families)]
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/software/mambaforge/envs/MOBI-DICK/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/arno01m/Downloads/batch2_final_viral_hits.csv'

# %%
print("Total virus hits: ", len(virus_hits))

print("Total vert virus hits: ", len(vert_virus_hits))
# Out:
# Total virus hits:  22250
# Total vert virus hits:  462

# %%
# convert family column of virus hits to lowercase
virus_hits['family'] = virus_hits['family'].str.lower()

vert_virus_hits = virus_hits[virus_hits['family'].isin(vert_families)]
vert_virus_hits =  vert_virus_hits[vert_virus_hits['length'] >= 300]

# %%
vert_virus_hits.to_csv('/Users/arno01m/Downloads/vert_virus_hits.csv', index=False)

# %%
blast_filtered_diamond_df = pd.read_csv('~/SRAmining/RawData/batch2/reprocess_sensitive_060524/vertebrate_viral_hits.csv')

# %%
data_dir = '/home3/2574106a/SRAmining/RawData/batch2/reprocess_sensitive_060524'

contigs = [line for line in open(data_dir + '/all_contigs_hits.fa')]

sequences = []

for hit in blast_filtered_diamond_df.iterrows():
    hit = hit[1]

    contig_id = '>' + hit['sample'] + '|' + hit.contig

    contig = subprocess.run(['grep', contig_id, data_dir + '/all_contigs_hits.fa', '-A', '1'], capture_output=True, text=True).stdout.split('\n')[1]

    sequences.append(contig)
    # for num, contig in enumerate(contigs):
    #     if contig.startswith('>' + hit['sample'] + '|' + hit.contig):
    #         sequences.append(contigs[num+1])
    #         break

blast_filtered_diamond_df['sequence'] = sequences

# %%
animals=['fish', 'amphibian', 'reptile', 'bird', 'mammal']
print(animals[1])
# Out:
# amphibian

# %%
# Out:
# True
